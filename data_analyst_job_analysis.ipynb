# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("job_analysis.csv")

# %%
data
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                                  Company Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy Apply
# 0                                                    -1       True
# 1                                                    -1         -1
# 2                                               GoDaddy         -1
# 3                                                    -1         -1
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                 -1         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2250                                                 -1         -1
# 2251                                                 -1         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1
#
# [2253 rows x 16 columns]

# %%
data.head(50).T
# Out:
#                                                                   0   \
# Unnamed: 0                                                         0
# Job Title          Data Analyst, Center on Immigration and Justic...
# Salary Estimate                           $37K-$66K (Glassdoor est.)
# Job Description    Are you eager to roll up your sleeves and harn...
# Rating                                                           3.2
# Company Name                          Vera Institute of Justice\n3.2
# Location                                                New York, NY
# Headquarters                                            New York, NY
# Size                                            201 to 500 employees
# Founded                                                         1961
# Type of ownership                             Nonprofit Organization
# Industry                                           Social Assistance
# Sector                                                    Non-Profit
# Revenue                                   $100 to $500 million (USD)
# Competitors                                                       -1
# Easy Apply                                                      True
#
#                                                                   1   \
# Unnamed: 0                                                         1
# Job Title                                       Quality Data Analyst
# Salary Estimate                           $37K-$66K (Glassdoor est.)
# Job Description    Overview\n\nProvides analytical and technical ...
# Rating                                                           3.8
# Company Name                 Visiting Nurse Service of New York\n3.8
# Location                                                New York, NY
# Headquarters                                            New York, NY
# Size                                                10000+ employees
# Founded                                                         1893
# Type of ownership                             Nonprofit Organization
# Industry                            Health Care Services & Hospitals
# Sector                                                   Health Care
# Revenue                                       $2 to $5 billion (USD)
# Competitors                                                       -1
# Easy Apply                                                        -1
#
#                                                                   2   \
# Unnamed: 0                                                         2
# Job Title          Senior Data Analyst, Insights & Analytics Team...
# Salary Estimate                           $37K-$66K (Glassdoor est.)
# Job Description    We’re looking for a Senior Data Analyst who ha...
# Rating                                                           3.4
# Company Name                                        Squarespace\n3.4
# Location                                                New York, NY
# Headquarters                                            New York, NY
# Size                                          1001 to 5000 employees
# Founded                                                         2003
# Type of ownership                                  Company - Private
# Industry                                                    Internet
# Sector                                        Information Technology
# Revenue                                     Unknown / Non-Applicable
# Competitors                                                  GoDaddy
# Easy Apply                                                        -1
#
#                                                                   3   \
# Unnamed: 0                                                         3
# Job Title                                               Data Analyst
# Salary Estimate                           $37K-$66K (Glassdoor est.)
# Job Description    Requisition NumberRR-0001939\nRemote:Yes\nWe c...
# Rating                                                           4.1
# Company Name                                           Celerity\n4.1
# Location                                                New York, NY
# Headquarters                                              McLean, VA
# Size                                            201 to 500 employees
# Founded                                                         2002
# Type of ownership                     Subsidiary or Business Segment
# Industry                                                 IT Services
# Sector                                        Information Technology
# Revenue                                    $50 to $100 million (USD)
# Competitors                                                       -1
# Easy Apply                                                        -1
#
#                                                                   4   \
# Unnamed: 0                                                         4
# Job Title                                     Reporting Data Analyst
# Salary Estimate                           $37K-$66K (Glassdoor est.)
# Job Description    ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...
# Rating                                                           3.9
# Company Name                                            FanDuel\n3.9
# Location                                                New York, NY
# Headquarters                                            New York, NY
# Size                                           501 to 1000 employees
# Founded                                                         2009
# Type of ownership                                  Company - Private
# Industry                                         Sports & Recreation
# Sector                              Arts, Entertainment & Recreation
# Revenue                                   $100 to $500 million (USD)
# Competitors                                               DraftKings
# Easy Apply                                                      True
#
#                                                                   5   \
# Unnamed: 0                                                         5
# Job Title                                               Data Analyst
# Salary Estimate                           $37K-$66K (Glassdoor est.)
# Job Description    About Cubist\nCubist Systematic Strategies is ...
# Rating                                                           3.9
# Company Name                                            Point72\n3.9
# Location                                                New York, NY
# Headquarters                                            Stamford, CT
# Size                                          1001 to 5000 employees
# Founded                                                         2014
# Type of ownership                                  Company - Private
# Industry                       Investment Banking & Asset Management
# Sector                                                       Finance
# Revenue                                     Unknown / Non-Applicable
# Competitors                                                       -1
# Easy Apply                                                        -1
#
#                                                                   6   \
# Unnamed: 0                                                         6
# Job Title                               Business/Data Analyst (FP&A)
# Salary Estimate                           $37K-$66K (Glassdoor est.)
# Job Description    Two Sigma is a different kind of investment ma...
# Rating                                                           4.4
# Company Name                                          Two Sigma\n4.4
# Location                                                New York, NY
# Headquarters                                            New York, NY
# Size                                          1001 to 5000 employees
# Founded                                                         2001
# Type of ownership                                  Company - Private
# Industry                       Investment Banking & Asset Management
# Sector                                                       Finance
# Revenue                                     Unknown / Non-Applicable
# Competitors                                                       -1
# Easy Apply                                                        -1
#
#                                                                   7   \
# Unnamed: 0                                                         7
# Job Title                                       Data Science Analyst
# Salary Estimate                           $37K-$66K (Glassdoor est.)
# Job Description    Data Science Analyst\n\nJob Details\nLevel\nEx...
# Rating                                                           3.7
# Company Name                            GNY Insurance Companies\n3.7
# Location                                                New York, NY
# Headquarters                                            New York, NY
# Size                                            201 to 500 employees
# Founded                                                         1914
# Type of ownership                                  Company - Private
# Industry                                          Insurance Carriers
# Sector                                                     Insurance
# Revenue                                   $100 to $500 million (USD)
# Competitors                         Travelers, Chubb, Crum & Forster
# Easy Apply                                                      True
#
#                                                                   8   \
# Unnamed: 0                                                         8
# Job Title                                               Data Analyst
# Salary Estimate                           $37K-$66K (Glassdoor est.)
# Job Description    The Data Analyst is an integral member of the ...
# Rating                                                             4
# Company Name                                               DMGT\n4.0
# Location                                                New York, NY
# Headquarters                                  London, United Kingdom
# Size                                         5001 to 10000 employees
# Founded                                                         1896
# Type of ownership                                   Company - Public
# Industry                            Venture Capital & Private Equity
# Sector                                                       Finance
# Revenue                                       $1 to $2 billion (USD)
# Competitors                         Thomson Reuters, Hearst, Pearson
# Easy Apply                                                        -1
#
#                                                                   9   ...  \
# Unnamed: 0                                                         9  ...
# Job Title                              Data Analyst, Merchant Health  ...
# Salary Estimate                           $37K-$66K (Glassdoor est.)  ...
# Job Description    About Us\n\nRiskified is the AI platform power...  ...
# Rating                                                           4.4  ...
# Company Name                                          Riskified\n4.4  ...
# Location                                                New York, NY  ...
# Headquarters                                            New York, NY  ...
# Size                                           501 to 1000 employees  ...
# Founded                                                         2013  ...
# Type of ownership                                  Company - Private  ...
# Industry                                      Research & Development  ...
# Sector                                             Business Services  ...
# Revenue                                     Unknown / Non-Applicable  ...
# Competitors                                         Signifyd, Forter  ...
# Easy Apply                                                        -1  ...
#
#                                                                   40  \
# Unnamed: 0                                                        40
# Job Title                           Business Analyst, Data Platforms
# Salary Estimate                           $46K-$87K (Glassdoor est.)
# Job Description    Company Description\n\nPinto is building the w...
# Rating                                                            -1
# Company Name                                                   Pinto
# Location                                                New York, NY
# Headquarters                                            New York, NY
# Size                                               1 to 50 employees
# Founded                                                           -1
# Type of ownership                                  Company - Private
# Industry                                                          -1
# Sector                                                            -1
# Revenue                                     Unknown / Non-Applicable
# Competitors                                                       -1
# Easy Apply                                                        -1
#
#                                                                   41  \
# Unnamed: 0                                                        41
# Job Title                                    Behavioral Data Analyst
# Salary Estimate                           $46K-$87K (Glassdoor est.)
# Job Description    About AB InBev\n\nAB InBev is the leading glob...
# Rating                                                            -1
# Company Name                                                AB InBev
# Location                                                New York, NY
# Headquarters                                           Kyiv, Ukraine
# Size                                          1001 to 5000 employees
# Founded                                                           -1
# Type of ownership                                   Company - Public
# Industry                                                          -1
# Sector                                                            -1
# Revenue                                     Unknown / Non-Applicable
# Competitors                                                       -1
# Easy Apply                                                        -1
#
#                                                                   42  \
# Unnamed: 0                                                        42
# Job Title                                               Data Analyst
# Salary Estimate                           $46K-$87K (Glassdoor est.)
# Job Description    Whip Media Group's products, including Mediamo...
# Rating                                                             5
# Company Name                                   Whip Media Group\n5.0
# Location                                                New York, NY
# Headquarters                                        Santa Monica, CA
# Size                                             51 to 200 employees
# Founded                                                         2016
# Type of ownership                                  Company - Private
# Industry                                                          -1
# Sector                                                            -1
# Revenue                                     Unknown / Non-Applicable
# Competitors                                                       -1
# Easy Apply                                                        -1
#
#                                                                   43  \
# Unnamed: 0                                                        43
# Job Title                       Data Analyst -1+ year Contract - NYC
# Salary Estimate                           $46K-$87K (Glassdoor est.)
# Job Description    Title: Data Analyst\n\nPosition: 1+ Year Contr...
# Rating                                                             4
# Company Name                           Two95 International Inc.\n4.0
# Location                                                New York, NY
# Headquarters                                         Cherry Hill, NJ
# Size                                               1 to 50 employees
# Founded                                                           -1
# Type of ownership                                  Company - Private
# Industry                                      Staffing & Outsourcing
# Sector                                             Business Services
# Revenue                                       $1 to $5 million (USD)
# Competitors                                                       -1
# Easy Apply                                                        -1
#
#                                                                   44  \
# Unnamed: 0                                                        44
# Job Title                                               Data Analyst
# Salary Estimate                           $46K-$87K (Glassdoor est.)
# Job Description    Vettery is changing the way people hire and ge...
# Rating                                                             3
# Company Name                                            Vettery\n3.0
# Location                                                New York, NY
# Headquarters                                            New York, NY
# Size                                            201 to 500 employees
# Founded                                                         2013
# Type of ownership                                  Company - Private
# Industry                                                    Internet
# Sector                                        Information Technology
# Revenue                                     Unknown / Non-Applicable
# Competitors                                 Hired, Indeed, AngelList
# Easy Apply                                                        -1
#
#                                                                   45  \
# Unnamed: 0                                                        45
# Job Title                                               Data Analyst
# Salary Estimate                           $46K-$87K (Glassdoor est.)
# Job Description    Non-Exempt*\nSchedule: Can be 8a.m. – 5p.m. or...
# Rating                                                           2.9
# Company Name                                Nesco Resource, LLC\n2.9
# Location                                                New York, NY
# Headquarters                                           Cleveland, OH
# Size                                          1001 to 5000 employees
# Founded                                                         1956
# Type of ownership                                  Company - Private
# Industry                                      Staffing & Outsourcing
# Sector                                             Business Services
# Revenue                             $500 million to $1 billion (USD)
# Competitors                                                       -1
# Easy Apply                                                        -1
#
#                                                                   46  \
# Unnamed: 0                                                        46
# Job Title                                   Advertising Data Analyst
# Salary Estimate                           $46K-$87K (Glassdoor est.)
# Job Description    Advertising Data AnalystHearst Television is s...
# Rating                                                             4
# Company Name                              Hearst Communications\n4.0
# Location                                                New York, NY
# Headquarters                                       San Francisco, CA
# Size                                               1 to 50 employees
# Founded                                                           -1
# Type of ownership                                  Company - Private
# Industry                                     Advertising & Marketing
# Sector                                             Business Services
# Revenue                                   Less than $1 million (USD)
# Competitors                                                       -1
# Easy Apply                                                        -1
#
#                                                                   47  \
# Unnamed: 0                                                        47
# Job Title                                               Data Analyst
# Salary Estimate                           $46K-$87K (Glassdoor est.)
# Job Description    MediaMath is a leading global independent adve...
# Rating                                                           3.6
# Company Name                                          MediaMath\n3.6
# Location                                                New York, NY
# Headquarters                                            New York, NY
# Size                                           501 to 1000 employees
# Founded                                                         2007
# Type of ownership                                  Company - Private
# Industry                                     Advertising & Marketing
# Sector                                             Business Services
# Revenue                                   $100 to $500 million (USD)
# Competitors                                 Criteo, AppNexus, dataxu
# Easy Apply                                                      True
#
#                                                                   48  \
# Unnamed: 0                                                        48
# Job Title                              Market Data Reporting Analyst
# Salary Estimate                           $46K-$87K (Glassdoor est.)
# Job Description    Employment PermanentApply\nStart Date Immediat...
# Rating                                                           4.9
# Company Name                                    Jordan & Jordan\n4.9
# Location                                                New York, NY
# Headquarters                                            New York, NY
# Size                                               1 to 50 employees
# Founded                                                         1990
# Type of ownership                                  Company - Private
# Industry                                          Brokerage Services
# Sector                                                       Finance
# Revenue                                     Unknown / Non-Applicable
# Competitors                                                       -1
# Easy Apply                                                        -1
#
#                                                                   49
# Unnamed: 0                                                        49
# Job Title                               Senior Analyst, Data Science
# Salary Estimate                           $46K-$87K (Glassdoor est.)
# Job Description    The Role:\n\nRoku is looking for a Senior Anal...
# Rating                                                           3.9
# Company Name                                               Roku\n3.9
# Location                                                New York, NY
# Headquarters                                            San Jose, CA
# Size                                          1001 to 5000 employees
# Founded                                                         2002
# Type of ownership                                   Company - Public
# Industry                                                 IT Services
# Sector                                        Information Technology
# Revenue                             $500 million to $1 billion (USD)
# Competitors                                                       -1
# Easy Apply                                                        -1
#
# [16 rows x 50 columns]

# %%
data.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
data['Competitors'].value_counts()
# Out:
# -1                                                      1732
# Adecco, Manpower                                          14
# Robert Half, Insight Global                               14
# Artech Information Systems, Mindlance, Tech Mahindra      10
# TEKsystems, Insight Global, Accenture                     10
#                                                         ...
# LinkedIn                                                   1
# Yardi Systems, AppFolio                                    1
# Fidelity Investments, Vanguard                             1
# Paxata, Datameer, Informatica                              1
# Booz Allen Hamilton, Abt Associates, Oliver Wyman          1
# Name: Competitors, Length: 291, dtype: int64

# %%
data['Easy Apply'].value_counts()
# Out:
# -1      2173
# True      80
# Name: Easy Apply, dtype: int64

# %%
data['Rating'].value_counts()[:5]
# Out:
# -1.0    272
#  3.9    140
#  3.6    135
#  3.7    132
#  5.0    131
# Name: Rating, dtype: int64

# %%
data=data.replace(-1,np.nan)
data=data.replace(-1.0,np.nan)
data=data.replace('-1',np.nan)

# %%
plt.rcParams["figure.figsize"] = (12,9)
#plt.style.use("classic")
color = plt.cm.PuRd(np.linspace(0,1,20))
data["Company Name"].value_counts().sort_values(ascending=False).head(20).plot.bar()
plt.title("Top 20 Company with Highest number of Jobs ",fontsize=20)
plt.xlabel("Company Name",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.show()

# %%
#   Top 20 Company with highest number of Jobs

# %%
com =data['Company Name'].value_counts()
company = pd.DataFrame({'Company': com.index,'Number of Jobs':com.values})
company.head(60)
# Out:
#                                           Company  Number of Jobs
# 0           Staffigo Technical Services, LLC\n5.0              58
# 1                               Diverse Lynx\n3.9              22
# 2                                     Kforce\n4.1              19
# 3                    Lorven Technologies Inc\n4.0              19
# 4                                Robert Half\n3.5              14
# 5                              Avacend, Inc.\n2.5              13
# 6                                      Mondo\n3.9              11
# 7                                      Apple\n4.1              10
# 8                                 eTeam Inc.\n3.7              10
# 9                               Apex Systems\n3.8              10
# 10                APN Software Services Inc.\n4.1               9
# 11               Reliable Software Resources\n4.0               9
# 12                                   TechUSA\n2.7               8
# 13                                 Capgemini\n3.8               7
# 14                                      Citi\n3.7               7
# 15                                      MUFG\n3.1               7
# 16               The Bank of New York Mellon\n3.2               7
# 17                                 Collabera\n4.1               7
# 18                      Infotree Service Inc\n3.7               6
# 19                Avani Technology Solutions\n4.5               6
# 20                         Molina Healthcare\n3.1               6
# 21                                Perficient\n3.6               6
# 22                       Centene Corporation\n3.3               5
# 23                                     Kelly\n3.4               5
# 24                     The Judge Group, Inc.\n3.5               5
# 25                            JPMorgan Chase\n3.9               5
# 26                           Amazon Corporate LLC               5
# 27                                    Acumen\n3.2               5
# 28                  Two95 International Inc.\n4.0               5
# 29  Texas Health & Human Services Commission\n2.8               5
# 30                      Praescient Analytics\n3.1               5
# 31                     Kforce Technology Staffing               5
# 32                                       SGA Inc.               5
# 33                              UC San Diego\n4.3               5
# 34                               Akraya Inc.\n4.6               5
# 35                University of Pennsylvania\n4.3               5
# 36                                      Vaco\n3.3               5
# 37                           Softcom Systems\n4.4               5
# 38                     Microsoft Corporation\n4.3               5
# 39                 22nd Century Technologies\n3.7               5
# 40                                  Vanguard\n3.2               5
# 41                                Amyx, Inc.\n4.0               4
# 42                Mount Sinai Medical Center\n3.1               4
# 43                                     TalentDash               4
# 44                                  AppleOne\n3.3               4
# 45                   ClientSolv Technologies\n3.3               4
# 46                               Orbis, Inc.\n4.9               4
# 47                                  Randstad\n3.7               4
# 48                                Net2Source\n3.2               4
# 49                           TEKsystems, Inc\n3.9               4
# 50                         Kaiser Permanente\n4.0               4
# 51                                    Lowe's\n3.3               4
# 52                                  Kelly IT\n3.4               4
# 53                           Mitchell Martin\n4.1               4
# 54                        NYU Langone Health\n4.0               4
# 55                          The Accuro Group\n3.0               4
# 56                    Chicago Public Schools\n3.5               4
# 57                           Georgia IT Inc.\n5.0               4
# 58                                    TikTok\n3.8               4
# 59                     Signature Consultants\n3.6               4

# %%
#  Number of Jobs according to Different Company

# %%
data["Job Title"].value_counts().sort_values(ascending=False).head(20).plot.bar()
plt.title("Top 20 Jobs of Data Analyst ",fontsize=20)
plt.xlabel("Job Title",fontsize=15)
plt.ylabel("Count",fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %%
#    Popular Jobs of Data Analyst

# %%
data["Location"].value_counts().sort_values(ascending=False).head(20).plot.bar()
plt.title("Top 20 locations for Data Analysts Job",fontsize=20)
plt.xlabel("Locations",fontsize=15)
plt.ylabel("Count",fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %%
#     Top 20 locations for Data Analysts Jobs

# %%
data["Headquarters"].value_counts().sort_values(ascending=False).head(20).plot.bar()
plt.title("Top 20 Head Quarters of Data Analysts Job Holder Company",fontsize=20)
plt.xlabel("Head Quarters",fontsize=15)
plt.ylabel("Count",fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %%
#   Top 20 Head Quarters of Data Analyst Job Holder Company

# %%
data["Founded"].value_counts().sort_values(ascending=False).head(20).plot.bar()
plt.title("Number of Company's Foundation in a Year",fontsize=20)
plt.xlabel("Company's Foundation Year",fontsize=15)
plt.ylabel("Count",fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %%
#   Highest number of Company Founded in a Year

# %%
data["Type of ownership"].value_counts().sort_values(ascending=False).head(20).plot.bar()
plt.title("Type of ownership",fontsize=20)
plt.xlabel("Ownership",fontsize=15)
plt.ylabel("Count",fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %%
#   Above graphs shows the types of Ownership. A higher number of Company's are Private almost 1300 & just 500 company's are Public

# %%
data["Sector"].value_counts().sort_values(ascending=False).head(20).plot.bar()
plt.title("Different types of Sectors for Data Analyst Jobs",fontsize=20)
plt.xlabel("Sectors",fontsize=15)
plt.ylabel("Count",fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %%
#   Most of the Data Analyst jobs are for the sector of Information Technology

# %%
rating = data.groupby(['Company Name'])[['Company Name','Rating']]
rating.head().nlargest(10,'Rating').style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_88a54f6d_1077_11eb_8950_8230493a0f9brow0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_88a54f6d_1077_11eb_8950_8230493a0f9brow1_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_88a54f6d_1077_11eb_8950_8230493a0f9brow2_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_88a54f6d_1077_11eb_8950_8230493a0f9brow3_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_88a54f6d_1077_11eb_8950_8230493a0f9brow4_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_88a54f6d_1077_11eb_8950_8230493a0f9brow5_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_88a54f6d_1077_11eb_8950_8230493a0f9brow6_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_88a54f6d_1077_11eb_8950_8230493a0f9brow7_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_88a54f6d_1077_11eb_8950_8230493a0f9brow8_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_88a54f6d_1077_11eb_8950_8230493a0f9brow9_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_88a54f6d_1077_11eb_8950_8230493a0f9b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Company Name</th>        <th class="col_heading level0 col1" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_88a54f6d_1077_11eb_8950_8230493a0f9blevel0_row0" class="row_heading level0 row0" >26</th>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow0_col0" class="data row0 col0" >Duolingo
# 5.0</td>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow0_col1" class="data row0 col1" >5.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_88a54f6d_1077_11eb_8950_8230493a0f9blevel0_row1" class="row_heading level0 row1" >42</th>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow1_col0" class="data row1 col0" >Whip Media Group
# 5.0</td>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow1_col1" class="data row1 col1" >5.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_88a54f6d_1077_11eb_8950_8230493a0f9blevel0_row2" class="row_heading level0 row2" >78</th>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow2_col0" class="data row2 col0" >Mulberry Technology
# 5.0</td>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow2_col1" class="data row2 col1" >5.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_88a54f6d_1077_11eb_8950_8230493a0f9blevel0_row3" class="row_heading level0 row3" >81</th>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow3_col0" class="data row3 col0" >EDO, Inc.
# 5.0</td>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow3_col1" class="data row3 col1" >5.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_88a54f6d_1077_11eb_8950_8230493a0f9blevel0_row4" class="row_heading level0 row4" >106</th>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow4_col0" class="data row4 col0" >Crossfire Consulting Corporation
# 5.0</td>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow4_col1" class="data row4 col1" >5.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_88a54f6d_1077_11eb_8950_8230493a0f9blevel0_row5" class="row_heading level0 row5" >114</th>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow5_col0" class="data row5 col0" >Averity
# 5.0</td>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow5_col1" class="data row5 col1" >5.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_88a54f6d_1077_11eb_8950_8230493a0f9blevel0_row6" class="row_heading level0 row6" >124</th>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow6_col0" class="data row6 col0" >Staffigo Technical Services, LLC
# 5.0</td>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow6_col1" class="data row6 col1" >5.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_88a54f6d_1077_11eb_8950_8230493a0f9blevel0_row7" class="row_heading level0 row7" >146</th>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow7_col0" class="data row7 col0" >Crossfire Consulting Corporation
# 5.0</td>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow7_col1" class="data row7 col1" >5.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_88a54f6d_1077_11eb_8950_8230493a0f9blevel0_row8" class="row_heading level0 row8" >206</th>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow8_col0" class="data row8 col0" >VISTRADA
# 5.0</td>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow8_col1" class="data row8 col1" >5.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_88a54f6d_1077_11eb_8950_8230493a0f9blevel0_row9" class="row_heading level0 row9" >211</th>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow9_col0" class="data row9 col0" >Staffigo Technical Services, LLC
# 5.0</td>
#                         <td id="T_88a54f6d_1077_11eb_8950_8230493a0f9brow9_col1" class="data row9 col1" >5.000000</td>
#             </tr>
#     </tbody></table>

# %%
#  Above are Company with Highest Number of Rating

# %%
rating.head().nlargest(30,'Rating').plot.bar(x='Company Name',y='Rating')
plt.title("Top 30 Company with highest number of Rating",fontsize=20)
plt.xlabel("Company Name",fontsize=15)
plt.ylabel("Rating",fontsize=15)
# Out:
# Text(0, 0.5, 'Rating')

# %%
data['Rating'] = data['Rating'].replace(-1,np.NaN)
data['Rating'].value_counts().plot.bar(x='Rating',y='No. of Companies',)
plt.title("Number of Companies with specific Rating",fontsize=20)
plt.xlabel("Rating",fontsize=15)
plt.ylabel("No. of Company",fontsize=15)
plt.show()

# %%
#   So, this is all about analysis.
